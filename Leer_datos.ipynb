# %%
pip install pandas matplotlib seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("data.csv")

# %%
df.head(1)
# Out:
#                                id_venta  id_cliente          nombre  edad  \
# 0  20917b10-7ac0-4a89-9b05-cbb695372a1b       14812  Bridget Ramsey    20
#
#   procedencia       fecha   hora categoria  duracion_min  precio metodo_pago
# 0  Jonesmouth  2024-05-17  13:23   pequeño            72      94    efectivo

# %%
df["categoria"].value_counts()
# Out:
# categoria
# pequeño    50190
# mediano    34826
# grande     14984
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df,
              x="categoria",
              order=df["categoria"].value_counts().index
             )

plt.title("Cantidad de ventas por categoria")
plt.show()

# %%
df["dia_semana"] = pd.to_datetime(df["fecha"]).dt.day_name()

plt.figure(figsize=(8, 5))
sns.countplot(data=df,
              x="dia_semana",
              order=["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]
             )

plt.title("Cantidad de ventas por dia de la semana")
plt.show()

# %%
plt.figure(figsize=(12, 5))

sns.histplot(df["hora"], bins=12,kde=True)

plt.title("Cantidad de ventas por hora del dia")
plt.show()

# %%
sns.histplot(data=df, x="precio", hue="categoria", multiple="stack")
# Out:
# <Axes: xlabel='precio', ylabel='Count'>

# %%
g = sns.relplot(data=df, x="precio", y="duracion_min")
